# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({"revenue":[57,68,63,71,72,90,80,62,59,51,47,92],
                   "advertising":[2.1,1.9,2.7,3.0,3.6,3.2,2.7,2.4,1.8,1.6,1.3,1.9],
                   "month":range(12)
                  })

fig, ax = plt.subplots()
ax2 = ax.twiny()

df.plot(kind='bar', x='month' ,y='revenue', ax=ax, color="pink")
df.plot(kind='line', x='month', y='advertising', ax=ax, color="red")

plt.show()
